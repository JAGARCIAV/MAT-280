# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(iris.petal_length, iris.petal_width)

# %%
plt.scatter(iris["petal_length"], iris["petal_width"])

# %%
sns.scatterplot(x="petal_length", y="petal_width", data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.set_style("darkgrid")  # También: "whitegrid", "dark", "white", "ticks"
sns.scatterplot(x="petal_length", y="petal_width", size="sepal_length", data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.set_style("darkgrid") 
sns.scatterplot(x="petal_length", y="petal_width", size="sepal_length", sizes=(30, 150), data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10, 6))
sns.scatterplot(x="petal_length", y="petal_width", size="sepal_length", sizes=(30, 100), data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10, 6))
sns.scatterplot(x="petal_length", y="petal_width", size="sepal_length", sizes=(30, 100), data=iris, alpha=0.7)
plt.legend(bbox_to_anchor=(1.01, 1))

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10, 6))
sns.scatterplot(x="petal_length", y="petal_width", size="sepal_length", sizes=(30, 100), data=iris, alpha=0.7)
plt.legend(bbox_to_anchor=(1.01, 1))
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Petal Length vs Petal Width")
plt.show()

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10, 6))
sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris)
plt.legend(bbox_to_anchor=(1.01, 1))
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Petal Length vs Petal Width")
plt.show()
