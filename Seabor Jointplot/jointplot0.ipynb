# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", data=iris)
plt.show()

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", 
                data=iris, s=100, 
                marginal_ticks=True, 
                marginal_kws=dict(bins=25, fill=False))
g.fig.set_size_inches(8, 8)
g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
plt.show()

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", 
                data=iris, kind="reg", 
                marginal_ticks=True, 
                marginal_kws=dict(bins=25, fill=False))
g.fig.set_size_inches(8, 8)
g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
plt.show()

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", 
                data=iris, hue="species", 
                marginal_ticks=True)
g.fig.set_size_inches(8, 8)
g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
plt.show()

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", 
                data=iris, hue="species", kind="kde", 
                marginal_ticks=True)
g.fig.set_size_inches(8, 8)
g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
plt.show()

# %%
sns.set_style("dark")
g=sns.jointplot(x="sepal_length", y="sepal_width", 
                data=iris, hue="species", kind="hex", 
                marginal_ticks=True)
g.fig.set_size_inches(8, 8)
g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 sns.set_style("dark")
# ----> 2 g=sns.jointplot(x="sepal_length", y="sepal_width",
#       3                 data=iris, hue="species", kind="hex",
#       4                 marginal_ticks=True)
#       5 g.fig.set_size_inches(8, 8)
#       6 g.set_axis_labels("Sepal Length", "Sepal Width", fontsize=14)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\axisgrid.py:2228, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2226 if hue is not None and kind in ["hex", "reg", "resid"]:
#    2227     msg = f"Use of `hue` with `kind='{kind}'` is not currently supported."
# -> 2228     raise ValueError(msg)
#    2230 # Make a colormap based off the plot color
#    2231 # (Currently used only for kind="hex")
#    2232 if color is None:
#
# ValueError: Use of `hue` with `kind='hex'` is not currently supported.
