# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\_docstring.py:79, in _ArtistKwdocLoader.__missing__(self, key)
#      78 try:
# ---> 79     cls, = (cls for cls in _api.recursive_subclasses(Artist)
#      80             if cls.__name__ == name)
#      81 except ValueError as e:
#
# ValueError: too many values to unpack (expected 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)     50
#      51 ]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\utils.py:14
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
# ---> 14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#      17 from seaborn._core.typing import deprecated
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\pyplot.py:70
#      67 from matplotlib import _docstring
#      68 from matplotlib.backend_bases import (
#      69     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 70 from matplotlib.figure import Figure, FigureBase, figaspect
#      71 from matplotlib.gridspec import GridSpec, SubplotSpec
#      72 from matplotlib import rcsetup, rcParamsDefault, rcParamsOrig
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\figure.py:40
#      37 import numpy as np
#      39 import matplotlib as mpl
# ---> 40 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      41 from matplotlib.artist import (
#      42     Artist, allow_rasterization, _finalize_rasterization)
#      43 from matplotlib.backend_bases import (
#      44     DrawEvent, FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\projections\__init__.py:55
#       1 """
#       2 Non-separable transforms that map from data space to screen space.
#       3
#    (...)     52 `matplotlib.projections.polar` may also be of interest.
#      53 """
# ---> 55 from .. import axes, _docstring
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\axes\__init__.py:2
#       1 from . import _base
# ----> 2 from ._axes import Axes
#       4 # Backcompat.
#       5 Subplot = Axes
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\axes\_axes.py:68
#      63     func.__qualname__ = f"Axes.{func.__name__}"
#      64     return func
#      67 @_docstring.interpd
# ---> 68 class Axes(_AxesBase):
#      69     """
#      70     An Axes object encapsulates all the elements of an individual (sub-)plot in
#      71     a figure.
#    (...)     89
#      90     """
#      91     ### Labelling, legend and texts
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\axes\_axes.py:416, in Axes()
#     412     self.add_child_axes(inset_ax)
#     414     return inset_ax
# --> 416 @_docstring.interpd
#     417 def indicate_inset(self, bounds=None, inset_ax=None, *, transform=None,
#     418                    facecolor='none', edgecolor='0.5', alpha=0.5,
#     419                    zorder=None, **kwargs):
#     420     """
#     421     Add an inset indicator to the Axes.  This is a rectangle on the plot
#     422     at the position indicated by *bounds* that optionally has lines that
#    (...)    481             Previously the rectangle and connectors tuple were returned.
#     482     """
#     483     # to make the Axes connectors work, we need to apply the aspect to
#     484     # the parent Axes.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\_docstring.py:124, in _ArtistPropertiesSubstitution.__call__(self, obj)
#     122 def __call__(self, obj):
#     123     if obj.__doc__:
# --> 124         obj.__doc__ = inspect.cleandoc(obj.__doc__) % self.params
#     125     if isinstance(obj, type) and obj.__init__ != object.__init__:
#     126         self(obj.__init__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\_docstring.py:82, in _ArtistKwdocLoader.__missing__(self, key)
#      79     cls, = (cls for cls in _api.recursive_subclasses(Artist)
#      80             if cls.__name__ == name)
#      81 except ValueError as e:
# ---> 82     raise KeyError(key) from e
#      83 return self.setdefault(key, kwdoc(cls))
#
# KeyError: 'Rectangle:kwdoc'

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips, x="total_bill")

# %%
sns.displot(tips, x="total_bill", kde=True)

# %%
sns.displot(tips, x="total_bill", kde=True, rug=True)

# %%
sns.displot(tips, x="total_bill", kind="kde")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.displot(tips, x="total_bill", kind="kde")
#
# NameError: name 'sns' is not defined
